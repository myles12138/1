# %% [markdown]
# <h1>PART ONE

# %% [markdown]
# <h2> Step 1: Import the libraries

# %%
import matplotlib.pyplot as plt #data visulisation package
import pandas as pd #pandas to create dataframe
import seaborn as sns #seaborn for graph plots
import numpy as np #numpy for data manipulation

# %% [markdown]
# <h2>Step 2: Understand the data using pandas

# %%
group_27_data=pd.read_csv("group_27_data.csv")

# %% [markdown]
# <h3>Perform Exploratory Data Analysis (EDA)

# %% [markdown]
# Find out the data rows and columns. The first value=number of rows, the second value=number of columns. This sample dataset has 40 firm-year observations and 11 variables. The next line of code shows what these 11 variables are. **Report the total observations in your report**.

# %% [markdown]
# <h4>A. Data overview

# %%
group_27_data.shape
# Out:
# (756, 11)

# %%
group_27_data
# Out:
#     Company-Year                  Sector  stock_FinancialYEnd  \
# 0      ABBV-2020             Health Care            92.901733
# 1      ABBV-2021             Health Care           145.838837
# 2      ABBV-2022             Health Care           148.959747
# 3      ABBV-2023             Health Care           177.080963
# 4       ABT-2020             Health Care           112.091141
# ..           ...                     ...                  ...
# 751     YUM-2023  Consumer Discretionary           137.284927
# 752     ZBH-2020             Health Care           151.337921
# 753     ZBH-2021             Health Care           125.350670
# 754     ZBH-2022             Health Care           127.680733
# 755     ZBH-2023             Health Care           131.440140
#
#      stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 0                97.827057      2.62                 13,076,000
# 1               139.216965      6.53                 15,408,000
# 2               127.126350      6.69                 17,254,000
# 3               168.386169      2.75                 10,360,000
# 4               108.870796      2.54                 32,784,000
# ..                     ...       ...                        ...
# 751             131.812256      5.68                 -7,858,000
# 752             152.268951     -0.67                 12,194,200
# 753             103.163544      1.93                 12,660,700
# 754             144.162476      1.10                 12,020,300
# 755             108.289314      4.91                 12,480,500
#
#     Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0          1,765,133                  4,556,000                   49.567
# 1          1,768,338                 11,468,000                   48.067
# 2          1,769,181                 11,782,000                   47.600
# 3          1,765,941                  4,820,000                   49.317
# 4          1,771,230                  4,495,000                   50.567
# ..               ...                        ...                      ...
# 751          281,000                  1,597,000                   40.425
# 752          207,000                   -138,900                   49.683
# 753          208,600                    401,600                   49.217
# 754          209,600                    231,400                   48.504
# 755          208,700                  1,024,000                   48.800
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 0                    19.250                                   6.667
# 1                    19.890                                   5.000
# 2                    19.217                                   5.000
# 3                    19.960                                   5.000
# 4                    20.357                                   5.667
# ..                      ...                                     ...
# 751                  20.095                                   5.000
# 752                  15.613                                   7.000
# 753                  17.106                                   6.333
# 754                  20.749                                   5.000
# 755                  22.318                                   5.000
#
# [756 rows x 11 columns]

# %%
group_27_data.head()
# Out:
#   Company-Year       Sector  stock_FinancialYEnd  stock_FollowingQtrEnd  \
# 0    ABBV-2020  Health Care            92.901733              97.827057
# 1    ABBV-2021  Health Care           145.838837             139.216965
# 2    ABBV-2022  Health Care           148.959747             127.126350
# 3    ABBV-2023  Health Care           177.080963             168.386169
# 4     ABT-2020  Health Care           112.091141             108.870796
#
#    BasicEPS total shareholder's equity Basic avg shares  \
# 0      2.62                 13,076,000        1,765,133
# 1      6.53                 15,408,000        1,768,338
# 2      6.69                 17,254,000        1,769,181
# 3      2.75                 10,360,000        1,765,941
# 4      2.54                 32,784,000        1,771,230
#
#   NetIncomeAvailShareholders  ESG Risk Exposure Score  ESG Risk Managed Score  \
# 0                  4,556,000                   49.567                  19.250
# 1                 11,468,000                   48.067                  19.890
# 2                 11,782,000                   47.600                  19.217
# 3                  4,820,000                   49.317                  19.960
# 4                  4,495,000                   50.567                  20.357
#
#    Sustainalytics ESG Risk Classification
# 0                                   6.667
# 1                                   5.000
# 2                                   5.000
# 3                                   5.000
# 4                                   5.667

# %%
group_27_data.tail()
# Out:
#     Company-Year                  Sector  stock_FinancialYEnd  \
# 751     YUM-2023  Consumer Discretionary           137.284927
# 752     ZBH-2020             Health Care           151.337921
# 753     ZBH-2021             Health Care           125.350670
# 754     ZBH-2022             Health Care           127.680733
# 755     ZBH-2023             Health Care           131.440140
#
#      stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 751             131.812256      5.68                 -7,858,000
# 752             152.268951     -0.67                 12,194,200
# 753             103.163544      1.93                 12,660,700
# 754             144.162476      1.10                 12,020,300
# 755             108.289314      4.91                 12,480,500
#
#     Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 751          281,000                  1,597,000                   40.425
# 752          207,000                   -138,900                   49.683
# 753          208,600                    401,600                   49.217
# 754          209,600                    231,400                   48.504
# 755          208,700                  1,024,000                   48.800
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 751                  20.095                                   5.000
# 752                  15.613                                   7.000
# 753                  17.106                                   6.333
# 754                  20.749                                   5.000
# 755                  22.318                                   5.000

# %% [markdown]
# <h4>B. Data cleaning

# %% [markdown]
# <h5>Check if any column has missing values

# %% [markdown]
# If the second column in the output cell is all 0 means there is no missing observations. If ther is non-0 in the second column, consider dropping these variables (columns) or use other extrapoliation methods to fill the missing values. Report your findings.

# %%
group_27_data.isnull().sum()
# Out:
# Company-Year                              0
# Sector                                    0
# stock_FinancialYEnd                       0
# stock_FollowingQtrEnd                     0
# BasicEPS                                  0
# total shareholder's equity                0
# Basic avg shares                          0
# NetIncomeAvailShareholders                0
# ESG Risk Exposure Score                   0
# ESG Risk Managed Score                    0
# Sustainalytics ESG Risk Classification    0
# dtype: int64

# %% [markdown]
# List all the columns names

# %%
group_27_data.columns
# Out:
# Index(['Company-Year', 'Sector', 'stock_FinancialYEnd',
#        'stock_FollowingQtrEnd', 'BasicEPS', 'total shareholder's equity',
#        'Basic avg shares', 'NetIncomeAvailShareholders',
#        'ESG Risk Exposure Score', 'ESG Risk Managed Score',
#        'Sustainalytics ESG Risk Classification'],
#       dtype='object')

# %% [markdown]
# Show the observatoins under the `Sector` column.

# %% [markdown]
# Split the `Company-Year` column into two columns: Company, Year

# %%
group_27_data[['Company', 'Year']] = group_27_data['Company-Year'].str.split('-', expand=True)

# %% [markdown]
# Rename the dataframe

# %%
DATA=group_27_data

# %% [markdown]
# Drop the column `Company-Year`

# %%
DATA = DATA.drop(columns=['Company-Year'])

# %% [markdown]
# Find out the data type of `Sector`. If the answer is *float* or *int*, the variable is stored as a number; if it is *object* then the variable is stored as a string, pandas only reads *float* and *int* as numbers. At a later step, we will covert the string variables into *float* or *int* in order to run regression analysis.

# %%
print(DATA['Sector'].dtype)
# Out:
# object

# %% [markdown]
# For fixed effect analyses later, map each unique Sector with a dummy code and create a new variable/column SECTOR. In your scraped data, the Sectors maybe different, check what sectors you have first before the mapping. Report the process.

# %%
DATA['Sector'] = DATA['Sector'].astype('category')
 
DATA['SECTOR'] = DATA['Sector'].cat.codes + 1
 
sector_mapping = dict(enumerate(DATA['Sector'].cat.categories, start=1))
print("Sector Mapping:\n", sector_mapping)
# Out:
# Sector Mapping:
#  {1: 'Communication Services', 2: 'Consumer Discretionary', 3: 'Consumer Staples', 4: 'Energy', 5: 'Financials', 6: 'Health Care', 7: 'Industrials', 8: 'Materials', 9: 'Real Estate', 10: 'Utilities'}

# %% [markdown]
# Reorder the columns

# %%
DATA=DATA[['Company', 'Year','SECTOR', 'Sector', 'stock_FinancialYEnd', 'stock_FollowingQtrEnd', 'BasicEPS', 
           "total shareholder's equity",'Basic avg shares', 'NetIncomeAvailShareholders', 
           'ESG Risk Exposure Score', 'ESG Risk Managed Score', 'Sustainalytics ESG Risk Classification']]

# %% [markdown]
# Check your data and reporting the process.

# %%
DATA.head()
# Out:
#   Company  Year  SECTOR       Sector  stock_FinancialYEnd  \
# 0    ABBV  2020       6  Health Care            92.901733
# 1    ABBV  2021       6  Health Care           145.838837
# 2    ABBV  2022       6  Health Care           148.959747
# 3    ABBV  2023       6  Health Care           177.080963
# 4     ABT  2020       6  Health Care           112.091141
#
#    stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 0              97.827057      2.62                 13,076,000
# 1             139.216965      6.53                 15,408,000
# 2             127.126350      6.69                 17,254,000
# 3             168.386169      2.75                 10,360,000
# 4             108.870796      2.54                 32,784,000
#
#   Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0        1,765,133                  4,556,000                   49.567
# 1        1,768,338                 11,468,000                   48.067
# 2        1,769,181                 11,782,000                   47.600
# 3        1,765,941                  4,820,000                   49.317
# 4        1,771,230                  4,495,000                   50.567
#
#    ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 0                  19.250                                   6.667
# 1                  19.890                                   5.000
# 2                  19.217                                   5.000
# 3                  19.960                                   5.000
# 4                  20.357                                   5.667

# %% [markdown]
# <h4>C. Data Exploration

# %%
DATA[['Sector']]
# Out:
#                      Sector
# 0               Health Care
# 1               Health Care
# 2               Health Care
# 3               Health Care
# 4               Health Care
# ..                      ...
# 751  Consumer Discretionary
# 752             Health Care
# 753             Health Care
# 754             Health Care
# 755             Health Care
#
# [756 rows x 1 columns]

# %% [markdown]
# List the unique values under `Sector`, **report the findings**.

# %%
pd.unique(DATA['Sector'])
# Out:
# ['Health Care', 'Consumer Staples', 'Utilities', 'Financials', 'Materials', 'Industrials', 'Real Estate', 'Consumer Discretionary', 'Energy', 'Communication Services']
# Categories (10, object): ['Communication Services', 'Consumer Discretionary', 'Consumer Staples', 'Energy', ..., 'Industrials', 'Materials', 'Real Estate', 'Utilities']

# %% [markdown]
# How many rows (firms) under each `Sector`? **Report the findings.**

# %%
DATA['Sector'].value_counts()
# Out:
# Sector
# Consumer Discretionary    80
# Energy                    80
# Financials                80
# Health Care               80
# Industrials               80
# Materials                 80
# Real Estate               80
# Utilities                 80
# Consumer Staples          60
# Communication Services    56
# Name: count, dtype: int64

# %%
# Set white background without gridlines
sns.set_style("white")

# Count the number of firms by sector
sector_counts = DATA['Sector'].value_counts().sort_index()

# Create vertical bar chart
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    x=sector_counts.index, 
    y=sector_counts.values, 
    palette="Blues")

# Add counts on top of each bar
for i, v in enumerate(sector_counts.values):
    ax.text(i, v + 2, str(v), ha='center', fontsize=10)

# Add bold title with padding
plt.title('Firm Count by Sector', fontsize=16, fontweight='bold', pad=20, color='#1f77b4')

# Rotate x labels for clarity
plt.xticks(rotation=45)

ax.set_xlabel('') 

# Remove gridlines and y-axis ticks for a clean look
sns.despine(left=True, bottom=False)
ax.yaxis.set_ticks([])

# Adjust layout and display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_26020\1899567133.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
# Prepare data
sector_year_avg = DATA.groupby(['Sector', 'Year'])['stock_FinancialYEnd'].mean().reset_index()
pivot_df = sector_year_avg.pivot(index='Sector', columns='Year', values='stock_FinancialYEnd').sort_index()

# Color
colors = ['#003366', '#0066cc', '#3399ff', '#99ccff']  # dark blue → lighter blue

# Draw grouped bar chart
pivot_df.plot(
    kind='bar',
    figsize=(12, 7),
    width=0.75,
    color=colors)

# Title
plt.title('Average Stock Price by Sector and Year', fontsize=16, fontweight='bold', color='#1f77b4')
 
# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')
plt.xlabel('')

# Remove gridline
plt.grid(axis='y', linestyle='--', alpha=0.5)
sns.despine()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_26020\3930734872.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sector_year_avg = DATA.groupby(['Sector', 'Year'])['stock_FinancialYEnd'].mean().reset_index()

# %%
 #Prepare data: tính Basic EPS trung bình theo Sector và Year
sector_year_avg_eps = DATA.groupby(['Sector', 'Year'])['BasicEPS'].mean().reset_index()
pivot_df_eps = sector_year_avg_eps.pivot(index='Sector', columns='Year', values='BasicEPS').sort_index()
colors = ['#003366', '#0066cc', '#3399ff', '#99ccff']  # dark blue → lighter blue
pivot_df_eps.plot(
    kind='bar',
    figsize=(12, 7),
    width=0.75,
    color=colors)
plt.title('Average Basic EPS by Sector and Year', fontsize=16, fontweight='bold', color='#1f77b4')
plt.xticks(rotation=45, ha='right')
plt.xlabel('')
plt.grid(axis='y', linestyle='--', alpha=0.5)
sns.despine()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_26020\1227846849.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sector_year_avg_eps = DATA.groupby(['Sector', 'Year'])['BasicEPS'].mean().reset_index()

# %%
# Calculate yearly averages for the 3 ESG indicators
esg_year_avg = DATA.groupby('Year')[[
    'ESG Risk Exposure Score',
    'ESG Risk Managed Score',
    'Sustainalytics ESG Risk Classification'
]].mean().reset_index()

# Plot line chart
plt.figure(figsize=(10, 6))

# Blue gradient colors for lines
colors = ['#003366', '#336699', '#66a3cc']  # dark blue, medium blue, light blue

# Plot with thicker lines for clarity
plt.plot(esg_year_avg['Year'], esg_year_avg['ESG Risk Exposure Score'],
         marker='o', label='Risk Exposure Score', color=colors[0], linewidth=4)
plt.plot(esg_year_avg['Year'], esg_year_avg['ESG Risk Managed Score'],
         marker='o', label='Risk Managed Score', color=colors[1], linewidth=4)
plt.plot(esg_year_avg['Year'], esg_year_avg['Sustainalytics ESG Risk Classification'],
         marker='o', label='ESG Classification', color=colors[2], linewidth=4)

# Title
plt.title('ESG Indicators Over Years', fontsize=16, fontweight='bold', color='#1f77b4')

# Remove y-axis ticks and label
plt.yticks([])
plt.ylabel('')

# X-axis label
plt.xlabel('')
plt.xticks(fontsize=14)

# Remove all spines for clean look
sns.despine(left=True, bottom=True)

plt.legend(
    fontsize=10,
    loc='center left',
    bbox_to_anchor=(0.77, 0.6)
)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# Calculate average ESG scores by Sector
esg_sector_avg = DATA.groupby('Sector')[[
    'ESG Risk Exposure Score',
    'ESG Risk Managed Score',
    'Sustainalytics ESG Risk Classification'
]].mean().reset_index()

# Set 'Sector' as index for plotting
esg_sector_avg.set_index('Sector', inplace=True)

# Define blue gradient colors
colors = ['#003366', '#3399ff', '#99ccff']  # dark blue, medium blue, light blue

# Plot grouped bar chart
ax = esg_sector_avg.plot(
    kind='bar',
    figsize=(12, 7),
    width=0.75,
    color=colors
)

# Title
plt.title('Average ESG Scores by Sector', fontsize=16, fontweight='bold', color='#1f77b4')

# Rotate x labels for readability
plt.xticks(rotation=45, ha='right')

# Remove vertical gridlines, keep light horizontal gridlines
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Remove top and right spines
sns.despine()

# Remove Y axis labels and ticks
plt.ylabel('')
plt.xlabel('')
ax.yaxis.set_ticks([])

# Smaller legend
plt.legend(title='ESG Metrics', fontsize=10, title_fontsize=11)
sns.despine(left=True, bottom=True)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_26020\1969053642.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   esg_sector_avg = DATA.groupby('Sector')[[

# %%
DATA['Sector']!='Energy'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 751    True
# 752    True
# 753    True
# 754    True
# 755    True
# Name: Sector, Length: 756, dtype: bool

# %% [markdown]
# Find out what company is not in the "Energy" sector, "True" means that the company is not in the Energy sector.

# %%
DATA[DATA['Sector'] != 'Energy']
# Out:
#     Company  Year  SECTOR                  Sector  stock_FinancialYEnd  \
# 0      ABBV  2020       6             Health Care            92.901733
# 1      ABBV  2021       6             Health Care           145.838837
# 2      ABBV  2022       6             Health Care           148.959747
# 3      ABBV  2023       6             Health Care           177.080963
# 4       ABT  2020       6             Health Care           112.091141
# ..      ...   ...     ...                     ...                  ...
# 751     YUM  2023       2  Consumer Discretionary           137.284927
# 752     ZBH  2020       6             Health Care           151.337921
# 753     ZBH  2021       6             Health Care           125.350670
# 754     ZBH  2022       6             Health Care           127.680733
# 755     ZBH  2023       6             Health Care           131.440140
#
#      stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 0                97.827057      2.62                 13,076,000
# 1               139.216965      6.53                 15,408,000
# 2               127.126350      6.69                 17,254,000
# 3               168.386169      2.75                 10,360,000
# 4               108.870796      2.54                 32,784,000
# ..                     ...       ...                        ...
# 751             131.812256      5.68                 -7,858,000
# 752             152.268951     -0.67                 12,194,200
# 753             103.163544      1.93                 12,660,700
# 754             144.162476      1.10                 12,020,300
# 755             108.289314      4.91                 12,480,500
#
#     Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0          1,765,133                  4,556,000                   49.567
# 1          1,768,338                 11,468,000                   48.067
# 2          1,769,181                 11,782,000                   47.600
# 3          1,765,941                  4,820,000                   49.317
# 4          1,771,230                  4,495,000                   50.567
# ..               ...                        ...                      ...
# 751          281,000                  1,597,000                   40.425
# 752          207,000                   -138,900                   49.683
# 753          208,600                    401,600                   49.217
# 754          209,600                    231,400                   48.504
# 755          208,700                  1,024,000                   48.800
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 0                    19.250                                   6.667
# 1                    19.890                                   5.000
# 2                    19.217                                   5.000
# 3                    19.960                                   5.000
# 4                    20.357                                   5.667
# ..                      ...                                     ...
# 751                  20.095                                   5.000
# 752                  15.613                                   7.000
# 753                  17.106                                   6.333
# 754                  20.749                                   5.000
# 755                  22.318                                   5.000
#
# [676 rows x 13 columns]

# %% [markdown]
# Find out how many companies are NOT in the 'Energy' sector. In this output, the first number is the number of observations, i.e., companies. **Report your findings**.

# %%
DATA[DATA['Sector'] != 'Energy'].shape
# Out:
# (676, 13)

# %% [markdown]
# What are the 10 highest year-end `stock_FinancialYEnd` stock prices, the 10 highest quarter after the year-end `stock_FollowingQtrEnd` stock prices? **Report your findings**.

# %% [markdown]
# 10 highest year-end `stock_FinancialYEnd` stock prices

# %%
DATA.nlargest(10, ['stock_FinancialYEnd'])
# Out:
#     Company  Year  SECTOR                  Sector  stock_FinancialYEnd  \
# 507     NVR  2023       2  Consumer Discretionary          8099.959961
# 506     NVR  2022       2  Consumer Discretionary          5572.189941
# 504     NVR  2020       2  Consumer Discretionary          4710.930176
# 505     NVR  2021       2  Consumer Discretionary          4467.270020
# 527    ORLY  2023       2  Consumer Discretionary          1128.880005
# 526    ORLY  2022       2  Consumer Discretionary           848.979980
# 227    EQIX  2023       9             Real Estate           816.924316
# 699     URI  2023       7             Industrials           717.622681
# 225    EQIX  2021       9             Real Estate           706.652161
# 226    EQIX  2022       9             Real Estate           699.750061
#
#      stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 507            7588.560059    491.52                  4,364,725
# 506            6350.620117    525.20                  3,506,849
# 504            4973.299805    244.11                  3,103,074
# 505            4004.139893    345.37                  3,002,378
# 527            1056.060059     38.80                 -1,739,278
# 526             955.299988     33.75                 -1,060,752
# 227             752.547180     10.35                 12,488,894
# 699             645.187317     35.40                  8,130,000
# 225             628.745117      5.57                 10,882,082
# 226             764.488464      7.69                 11,505,966
#
#     Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 507            3,238                  1,591,611                   30.742
# 506            3,286                  1,725,575                   30.375
# 504            3,692                    901,248                   28.400
# 505            3,581                  1,236,719                   30.537
# 527           60,475                  2,346,581                   18.500
# 526           64,372                  2,172,650                   18.500
# 227           93,615                    969,178                   29.667
# 699           68,470                  2,424,000                   31.725
# 225           89,772                    500,191                   27.558
# 226           91,569                    704,345                   28.150
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 507                  10.277                                   5.000
# 506                   9.312                                   5.000
# 504                   8.401                                   4.091
# 505                   7.811                                   5.000
# 527                   6.450                                   3.000
# 526                   5.618                                   3.000
# 227                  17.521                                   3.000
# 699                  13.725                                   3.000
# 225                  12.781                                   3.000
# 226                  15.073                                   3.000

# %% [markdown]
# 10 highest quarter after the year-end `stock_FollowingQtrEnd` stock prices

# %%
DATA.nlargest(10, ['stock_FollowingQtrEnd'])
# Out:
#     Company  Year  SECTOR                  Sector  stock_FinancialYEnd  \
# 507     NVR  2023       2  Consumer Discretionary          8099.959961
# 506     NVR  2022       2  Consumer Discretionary          5572.189941
# 504     NVR  2020       2  Consumer Discretionary          4710.930176
# 505     NVR  2021       2  Consumer Discretionary          4467.270020
# 527    ORLY  2023       2  Consumer Discretionary          1128.880005
# 526    ORLY  2022       2  Consumer Discretionary           848.979980
# 226    EQIX  2022       9             Real Estate           699.750061
# 224    EQIX  2020       9             Real Estate           637.632629
# 227    EQIX  2023       9             Real Estate           816.924316
# 124    CHTR  2020       1  Communication Services           617.020020
#
#      stock_FollowingQtrEnd  BasicEPS total shareholder's equity  \
# 507            7588.560059    491.52                  4,364,725
# 506            6350.620117    525.20                  3,506,849
# 504            4973.299805    244.11                  3,103,074
# 505            4004.139893    345.37                  3,002,378
# 527            1056.060059     38.80                 -1,739,278
# 526             955.299988     33.75                 -1,060,752
# 226             764.488464      7.69                 11,505,966
# 224             756.300598      4.22                 10,633,988
# 227             752.547180     10.35                 12,488,894
# 124             721.450012     15.85                 23,805,000
#
#     Basic avg shares NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 507            3,238                  1,591,611                   30.742
# 506            3,286                  1,725,575                   30.375
# 504            3,692                    901,248                   28.400
# 505            3,581                  1,236,719                   30.537
# 527           60,475                  2,346,581                   18.500
# 526           64,372                  2,172,650                   18.500
# 226           91,569                    704,345                   28.150
# 224           87,700                    369,777                   27.350
# 227           93,615                    969,178                   29.667
# 124          203,316                  3,222,000                   28.150
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 507                  10.277                                   5.000
# 506                   9.312                                   5.000
# 504                   8.401                                   4.091
# 505                   7.811                                   5.000
# 527                   6.450                                   3.000
# 526                   5.618                                   3.000
# 226                  15.073                                   3.000
# 224                  11.188                                   3.000
# 227                  17.521                                   3.000
# 124                   8.101                                   4.167

# %% [markdown]
# <h2>Step 3: Descriptive Statistics

# %% [markdown]
# First, check the data types to see whether data transformation/conversion is required. **Write the process in your report**, i.e., how many are "object", what are they, and why you need to convert/transform them.

# %%
print(DATA.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Company                                 756 non-null    object
#  1   Year                                    756 non-null    object
#  2   SECTOR                                  756 non-null    int8
#  3   Sector                                  756 non-null    category
#  4   stock_FinancialYEnd                     756 non-null    float64
#  5   stock_FollowingQtrEnd                   756 non-null    float64
#  6   BasicEPS                                756 non-null    float64
#  7   total shareholder's equity              756 non-null    object
#  8   Basic avg shares                        756 non-null    object
#  9   NetIncomeAvailShareholders              756 non-null    object
#  10  ESG Risk Exposure Score                 756 non-null    float64
#  11  ESG Risk Managed Score                  756 non-null    float64
#  12  Sustainalytics ESG Risk Classification  756 non-null    float64
# dtypes: category(1), float64(6), int8(1), object(5)
# memory usage: 66.9+ KB
# None

# %% [markdown]
# `Year`,`total shareholder's equity`,`Basic avg shares`, `NetIncomeAvailShareholders` are strings separated by ","; pandas reads them as strings and won't treat them as numbers, we first need to convert them into float type. **Write the process in your report**.

# %%
cols=["Year","total shareholder's equity",'Basic avg shares','NetIncomeAvailShareholders']
DATA[cols]=DATA[cols].apply(lambda x: pd.to_numeric(x.astype(str).str.replace(',',''), errors='coerce'))

# %% [markdown]
# Check your data again after the conversion

# %%
print(DATA.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Company                                 756 non-null    object
#  1   Year                                    756 non-null    int64
#  2   SECTOR                                  756 non-null    int8
#  3   Sector                                  756 non-null    category
#  4   stock_FinancialYEnd                     756 non-null    float64
#  5   stock_FollowingQtrEnd                   756 non-null    float64
#  6   BasicEPS                                756 non-null    float64
#  7   total shareholder's equity              756 non-null    int64
#  8   Basic avg shares                        756 non-null    int64
#  9   NetIncomeAvailShareholders              756 non-null    int64
#  10  ESG Risk Exposure Score                 756 non-null    float64
#  11  ESG Risk Managed Score                  756 non-null    float64
#  12  Sustainalytics ESG Risk Classification  756 non-null    float64
# dtypes: category(1), float64(6), int64(4), int8(1), object(1)
# memory usage: 66.9+ KB
# None

# %% [markdown]
# Round the selected variables into 2 decimal places

# %%
DATA.round({"stock_FinancialYEnd":2, "stock_FollowingQtrEnd":2, "ESG Risk Exposure Score":2, 
            "ESG Risk Managed Score":2, "Sustainalytics ESG Risk Classification":2 })
# Out:
#     Company  Year  SECTOR                  Sector  stock_FinancialYEnd  \
# 0      ABBV  2020       6             Health Care                92.90
# 1      ABBV  2021       6             Health Care               145.84
# 2      ABBV  2022       6             Health Care               148.96
# 3      ABBV  2023       6             Health Care               177.08
# 4       ABT  2020       6             Health Care               112.09
# ..      ...   ...     ...                     ...                  ...
# 751     YUM  2023       2  Consumer Discretionary               137.28
# 752     ZBH  2020       6             Health Care               151.34
# 753     ZBH  2021       6             Health Care               125.35
# 754     ZBH  2022       6             Health Care               127.68
# 755     ZBH  2023       6             Health Care               131.44
#
#      stock_FollowingQtrEnd  BasicEPS  total shareholder's equity  \
# 0                    97.83      2.62                    13076000
# 1                   139.22      6.53                    15408000
# 2                   127.13      6.69                    17254000
# 3                   168.39      2.75                    10360000
# 4                   108.87      2.54                    32784000
# ..                     ...       ...                         ...
# 751                 131.81      5.68                    -7858000
# 752                 152.27     -0.67                    12194200
# 753                 103.16      1.93                    12660700
# 754                 144.16      1.10                    12020300
# 755                 108.29      4.91                    12480500
#
#      Basic avg shares  NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0             1765133                     4556000                    49.57
# 1             1768338                    11468000                    48.07
# 2             1769181                    11782000                    47.60
# 3             1765941                     4820000                    49.32
# 4             1771230                     4495000                    50.57
# ..                ...                         ...                      ...
# 751            281000                     1597000                    40.42
# 752            207000                     -138900                    49.68
# 753            208600                      401600                    49.22
# 754            209600                      231400                    48.50
# 755            208700                     1024000                    48.80
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification
# 0                     19.25                                    6.67
# 1                     19.89                                    5.00
# 2                     19.22                                    5.00
# 3                     19.96                                    5.00
# 4                     20.36                                    5.67
# ..                      ...                                     ...
# 751                   20.10                                    5.00
# 752                   15.61                                    7.00
# 753                   17.11                                    6.33
# 754                   20.75                                    5.00
# 755                   22.32                                    5.00
#
# [756 rows x 13 columns]

# %% [markdown]
# Create a new variable (book value to equity) `BVE`; **report the process**.

# %%
DATA['BVE'] = DATA["total shareholder's equity"] / DATA['Basic avg shares']

# %%
DATA
# Out:
#     Company  Year  SECTOR                  Sector  stock_FinancialYEnd  \
# 0      ABBV  2020       6             Health Care            92.901733
# 1      ABBV  2021       6             Health Care           145.838837
# 2      ABBV  2022       6             Health Care           148.959747
# 3      ABBV  2023       6             Health Care           177.080963
# 4       ABT  2020       6             Health Care           112.091141
# ..      ...   ...     ...                     ...                  ...
# 751     YUM  2023       2  Consumer Discretionary           137.284927
# 752     ZBH  2020       6             Health Care           151.337921
# 753     ZBH  2021       6             Health Care           125.350670
# 754     ZBH  2022       6             Health Care           127.680733
# 755     ZBH  2023       6             Health Care           131.440140
#
#      stock_FollowingQtrEnd  BasicEPS  total shareholder's equity  \
# 0                97.827057      2.62                    13076000
# 1               139.216965      6.53                    15408000
# 2               127.126350      6.69                    17254000
# 3               168.386169      2.75                    10360000
# 4               108.870796      2.54                    32784000
# ..                     ...       ...                         ...
# 751             131.812256      5.68                    -7858000
# 752             152.268951     -0.67                    12194200
# 753             103.163544      1.93                    12660700
# 754             144.162476      1.10                    12020300
# 755             108.289314      4.91                    12480500
#
#      Basic avg shares  NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0             1765133                     4556000                   49.567
# 1             1768338                    11468000                   48.067
# 2             1769181                    11782000                   47.600
# 3             1765941                     4820000                   49.317
# 4             1771230                     4495000                   50.567
# ..                ...                         ...                      ...
# 751            281000                     1597000                   40.425
# 752            207000                     -138900                   49.683
# 753            208600                      401600                   49.217
# 754            209600                      231400                   48.504
# 755            208700                     1024000                   48.800
#
#      ESG Risk Managed Score  Sustainalytics ESG Risk Classification        BVE
# 0                    19.250                                   6.667   7.407940
# 1                    19.890                                   5.000   8.713266
# 2                    19.217                                   5.000   9.752535
# 3                    19.960                                   5.000   5.866561
# 4                    20.357                                   5.667  18.509172
# ..                      ...                                     ...        ...
# 751                  20.095                                   5.000 -27.964413
# 752                  15.613                                   7.000  58.909179
# 753                  17.106                                   6.333  60.693672
# 754                  20.749                                   5.000  57.348760
# 755                  22.318                                   5.000  59.801150
#
# [756 rows x 14 columns]

# %% [markdown]
# <h2>Step 4: PCA analysis

# %% [markdown]
# Import liabraries to run PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# Create an index `esg_index` using PCA for all 3 ESG scores, and **report the process**.

# %%
esg_scores = DATA[['ESG Risk Exposure Score', 'ESG Risk Managed Score', 'Sustainalytics ESG Risk Classification']]

# %% [markdown]
# Standardise the features

# %%
scaler = StandardScaler()
esg_scores_scaled = scaler.fit_transform(esg_scores)

# %% [markdown]
# Apply PCA

# %%
pca = PCA(n_components=1)
esg_index = pca.fit_transform(esg_scores_scaled)

# %% [markdown]
# Create a new variable `ESG_Index` and add it to the dataframe

# %%
DATA['ESG_Index']=esg_index

# %%
DATA.head()
# Out:
#   Company  Year  SECTOR       Sector  stock_FinancialYEnd  \
# 0    ABBV  2020       6  Health Care            92.901733
# 1    ABBV  2021       6  Health Care           145.838837
# 2    ABBV  2022       6  Health Care           148.959747
# 3    ABBV  2023       6  Health Care           177.080963
# 4     ABT  2020       6  Health Care           112.091141
#
#    stock_FollowingQtrEnd  BasicEPS  total shareholder's equity  \
# 0              97.827057      2.62                    13076000
# 1             139.216965      6.53                    15408000
# 2             127.126350      6.69                    17254000
# 3             168.386169      2.75                    10360000
# 4             108.870796      2.54                    32784000
#
#    Basic avg shares  NetIncomeAvailShareholders  ESG Risk Exposure Score  \
# 0           1765133                     4556000                   49.567
# 1           1768338                    11468000                   48.067
# 2           1769181                    11782000                   47.600
# 3           1765941                     4820000                   49.317
# 4           1771230                     4495000                   50.567
#
#    ESG Risk Managed Score  Sustainalytics ESG Risk Classification        BVE  \
# 0                  19.250                                   6.667   7.407940
# 1                  19.890                                   5.000   8.713266
# 2                  19.217                                   5.000   9.752535
# 3                  19.960                                   5.000   5.866561
# 4                  20.357                                   5.667  18.509172
#
#    ESG_Index
# 0   0.772878
# 1   0.204997
# 2   0.141156
# 3   0.265873
# 4   0.563922

# %% [markdown]
# Check the variance loading, **report the variance loading in your report and interpret what the loading means**.

# %%
print("\nExplained variance ratio:", pca.explained_variance_ratio_[0])
# Out:
# Explained variance ratio: 0.7985368635439558

# %% [markdown]
# Show the loadings (importance) of each ESG score in the index. The highest loading is component 1, Python will creat a PCA using the highest loading. **Report the loading**.

# %%
loadings = pd.DataFrame(
    pca.components_.T,
    columns=['Loading'],
    index=['ESG Risk Exposure Score', 'ESG Risk Managed Score', 'Sustainalytics ESG Risk Classification']
)
print("\nPCA Loadings:")
print(loadings)
# Out:
# PCA Loadings:
#                                          Loading
# ESG Risk Exposure Score                 0.642701
# ESG Risk Managed Score                  0.554896
# Sustainalytics ESG Risk Classification  0.528228

# %% [markdown]
# ***Correlation matrix***

# %% [markdown]
# Perform correlation analysis and print out the heatmap.

# %% [markdown]
# Must specify the non-string variables otherwise the corr() code won't run. Save the matrix heatmap, **include it in your report**.

# %%
correlation_matrix = DATA[
    ['SECTOR', 'stock_FinancialYEnd', 'stock_FollowingQtrEnd', 'BasicEPS', "total shareholder's equity",
     'Basic avg shares', 'NetIncomeAvailShareholders', 'ESG Risk Exposure Score', 'ESG Risk Managed Score', 
     'Sustainalytics ESG Risk Classification', 'BVE', 'ESG_Index']
].corr()

plt.figure(figsize=(10, 8)) # Set up the matplotlib figure
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', center=0, fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')

plt.savefig('correlation_matrix_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Rename the columns, the statsmodels library does not recognise variables with 'space'.

# %%
DATA.rename(columns={"NetIncomeAvailShareholders": "profit", 
                     "ESG Risk Exposure Score": "ESG_Exposure", 
                     "ESG Risk Managed Score": "ESG_Managed", 
                     "Sustainalytics ESG Risk Classification": "ESG_Class"}, inplace=True)

# %% [markdown]
# Check the dataframe after renaming

# %%
DATA.head()
# Out:
#   Company  Year  SECTOR       Sector  stock_FinancialYEnd  \
# 0    ABBV  2020       6  Health Care            92.901733
# 1    ABBV  2021       6  Health Care           145.838837
# 2    ABBV  2022       6  Health Care           148.959747
# 3    ABBV  2023       6  Health Care           177.080963
# 4     ABT  2020       6  Health Care           112.091141
#
#    stock_FollowingQtrEnd  BasicEPS  total shareholder's equity  \
# 0              97.827057      2.62                    13076000
# 1             139.216965      6.53                    15408000
# 2             127.126350      6.69                    17254000
# 3             168.386169      2.75                    10360000
# 4             108.870796      2.54                    32784000
#
#    Basic avg shares    profit  ESG_Exposure  ESG_Managed  ESG_Class  \
# 0           1765133   4556000        49.567       19.250      6.667
# 1           1768338  11468000        48.067       19.890      5.000
# 2           1769181  11782000        47.600       19.217      5.000
# 3           1765941   4820000        49.317       19.960      5.000
# 4           1771230   4495000        50.567       20.357      5.667
#
#          BVE  ESG_Index
# 0   7.407940   0.772878
# 1   8.713266   0.204997
# 2   9.752535   0.141156
# 3   5.866561   0.265873
# 4  18.509172   0.563922

# %% [markdown]
# Save the new dataframe to csv

# %%
DATA.to_csv('DATA.csv')

# %% [markdown]
# <h1>PART TWO

# %% [markdown]
# <h2>Regression Analysis

# %% [markdown]
# We have provided a few different stats models here; choose the best model to interpet the results. Due to the random data scraping, you may find some models perform better/poorer, **export the results and include them in your report as sensitive analyses and state that you have tried other models**. Focus on interpretting the model(s) that yield the best results, i.e., with significant parameters (p-value<10%) of `BVE`, `BasicEPS`, `4 ESG scores` (try one score at a time, four scores in one model may not run as they are correlated).

# %% [markdown]
# <h2>Install fixed effect model and statsmodels

# %%
# %pip install FixedEffectModel
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# Requirement already satisfied: FixedEffectModel in c:\users\admin\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: pandas>=0.16.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from FixedEffectModel) (2.2.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\admin\appdata\roaming\python\python312\site-packages (from FixedEffectModel) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from FixedEffectModel) (1.13.1)
# Requirement already satisfied: statsmodels>=0.12.2 in c:\users\admin\appdata\roaming\python\python312\site-packages (from FixedEffectModel) (0.14.4)
# Requirement already satisfied: networkx>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from FixedEffectModel) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.16.0->FixedEffectModel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.16.0->FixedEffectModel) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.16.0->FixedEffectModel) (2023.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels>=0.12.2->FixedEffectModel) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels>=0.12.2->FixedEffectModel) (23.2)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.12.2->FixedEffectModel) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h2>Estimate a few simple Ohlsson models, export the tables that you think are important to Excel, report them in your report and discuss the results.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.914
# Model:                             OLS   Adj. R-squared:                  0.914
# Method:                  Least Squares   F-statistic:                     4023.
# Date:                 Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                         13:10:14   Log-Likelihood:                -4738.9
# No. Observations:                  756   AIC:                             9484.
# Df Residuals:                      753   BIC:                             9498.
# Df Model:                            2
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.4737      5.680      4.308      0.000      13.323      35.625
# BVE            1.7980      0.153     11.772      0.000       1.498       2.098
# BasicEPS       9.1982      0.392     23.487      0.000       8.429       9.967
# ==============================================================================
# Omnibus:                      349.831   Durbin-Watson:                   1.366
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18560.548
# Skew:                           1.290   Prob(JB):                         0.00
# Kurtosis:                      27.136   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# In the above regression model, the p-value for the coefficient of `BVE` is very small, indicating that `BVE` is a statistically significant predictor of `stock_FinancialYEnd`. This means there is strong evidence that `BVE` contributes to explaining the variations in `stock_FinancialYEnd`. If the p-value is large - greater than 10%, suggesting that `BVE` is not a statistically significant predictor at conventional levels.
#
# In the next model, we include `stock_FollowingQtrEnd` as an additional predictor variable to test its significance. You may consider experimenting with different combinations of variables to identify which ones significantly impact `stock_FinancialYEnd`. The results and significance of these variables will vary depending on the dataset used, so it is important to analyse the model output carefully for each specific case.
#
# You can also try using `profit` as the dependent (LHS) variable.

# %%
model=smf.ols('stock_FollowingQtrEnd ~ BVE + BasicEPS', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                       0.921
# Model:                               OLS   Adj. R-squared:                  0.921
# Method:                    Least Squares   F-statistic:                     4405.
# Date:                   Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                           13:10:17   Log-Likelihood:                -4707.1
# No. Observations:                    756   AIC:                             9420.
# Df Residuals:                        753   BIC:                             9434.
# Df Model:                              2
# Covariance Type:               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     26.1421      5.447      4.800      0.000      15.450      36.834
# BVE            1.5758      0.146     10.760      0.000       1.288       1.863
# BasicEPS       9.7972      0.376     26.090      0.000       9.060      10.534
# ==============================================================================
# Omnibus:                      454.600   Durbin-Watson:                   1.346
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11775.696
# Skew:                           2.217   Prob(JB):                         0.00
# Kurtosis:                      21.819   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS + stock_FollowingQtrEnd', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.989
# Model:                             OLS   Adj. R-squared:                  0.989
# Method:                  Least Squares   F-statistic:                 2.192e+04
# Date:                 Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                         13:10:19   Log-Likelihood:                -3973.8
# No. Observations:                  756   AIC:                             7956.
# Df Residuals:                      752   BIC:                             7974.
# Df Model:                            3
# Covariance Type:             nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.9256      2.098     -0.441      0.659      -5.043       3.192
# BVE                       0.2669      0.060      4.473      0.000       0.150       0.384
# BasicEPS                 -0.3206      0.197     -1.631      0.103      -0.706       0.065
# stock_FollowingQtrEnd     0.9716      0.014     70.282      0.000       0.944       0.999
# ==============================================================================
# Omnibus:                      495.280   Durbin-Watson:                   3.220
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           375538.250
# Skew:                          -1.523   Prob(JB):                         0.00
# Kurtosis:                     112.145   Cond. No.                         585.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Add ESG scores as an independent variable

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS + ESG_Index', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.920
# Model:                             OLS   Adj. R-squared:                  0.920
# Method:                  Least Squares   F-statistic:                     2885.
# Date:                 Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                         13:11:33   Log-Likelihood:                -4713.1
# No. Observations:                  756   AIC:                             9434.
# Df Residuals:                      752   BIC:                             9453.
# Df Model:                            3
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.0863      5.497      4.200      0.000      12.296      33.877
# BVE            1.8984      0.148     12.797      0.000       1.607       2.190
# BasicEPS       8.8755      0.381     23.275      0.000       8.127       9.624
# ESG_Index    -21.3471      2.929     -7.288      0.000     -27.097     -15.597
# ==============================================================================
# Omnibus:                      339.681   Durbin-Watson:                   1.389
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19506.437
# Skew:                           1.203   Prob(JB):                         0.00
# Kurtosis:                      27.768   Cond. No.                         113.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model=smf.ols('stock_FollowingQtrEnd ~ BVE + BasicEPS +ESG_Index ', data=DATA)
results=model.fit()
print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model=smf.ols('stock_FollowingQtrEnd ~ BVE + BasicEPS +ESG_Index ', data=DATA)
#       2 results=model.fit()
#       3 print(results.summary())
#
# NameError: name 'smf' is not defined

# %%
model=smf.ols('stock_FollowingQtrEnd ~ BVE + BasicEPS + ESG_Managed', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                       0.926
# Model:                               OLS   Adj. R-squared:                  0.926
# Method:                    Least Squares   F-statistic:                     3160.
# Date:                   Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                           12:55:57   Log-Likelihood:                -4681.1
# No. Observations:                    756   AIC:                             9370.
# Df Residuals:                        752   BIC:                             9389.
# Df Model:                              3
# Covariance Type:               nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      97.5187     11.081      8.800      0.000      75.765     119.272
# BVE             1.6652      0.142     11.717      0.000       1.386       1.944
# BasicEPS        9.4712      0.366     25.894      0.000       8.753      10.189
# ESG_Managed    -3.6510      0.499     -7.321      0.000      -4.630      -2.672
# ==============================================================================
# Omnibus:                      433.430   Durbin-Watson:                   1.349
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11835.494
# Skew:                           2.049   Prob(JB):                         0.00
# Kurtosis:                      21.946   Cond. No.                         237.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS + ESG_Managed', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.920
# Model:                             OLS   Adj. R-squared:                  0.920
# Method:                  Least Squares   F-statistic:                     2888.
# Date:                 Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                         12:55:57   Log-Likelihood:                -4712.7
# No. Observations:                  756   AIC:                             9433.
# Df Residuals:                      752   BIC:                             9452.
# Df Model:                            3
# Covariance Type:             nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      99.1471     11.554      8.581      0.000      76.465     121.829
# BVE             1.8914      0.148     12.764      0.000       1.601       2.182
# BasicEPS        8.8572      0.381     23.224      0.000       8.109       9.606
# ESG_Managed    -3.8197      0.520     -7.345      0.000      -4.841      -2.799
# ==============================================================================
# Omnibus:                      345.237   Durbin-Watson:                   1.383
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20118.702
# Skew:                           1.234   Prob(JB):                         0.00
# Kurtosis:                      28.152   Cond. No.                         237.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model=smf.ols('stock_FollowingQtrEnd ~ BVE + BasicEPS + ESG_Class', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                       0.923
# Model:                               OLS   Adj. R-squared:                  0.923
# Method:                    Least Squares   F-statistic:                     3021.
# Date:                   Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                           12:55:57   Log-Likelihood:                -4696.8
# No. Observations:                    756   AIC:                             9402.
# Df Residuals:                        752   BIC:                             9420.
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     86.2301     14.221      6.064      0.000      58.313     114.147
# BVE            1.6220      0.145     11.193      0.000       1.338       1.907
# BasicEPS       9.6821      0.372     26.061      0.000       8.953      10.411
# ESG_Class    -12.3749      2.711     -4.564      0.000     -17.698      -7.052
# ==============================================================================
# Omnibus:                      446.845   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11232.284
# Skew:                           2.172   Prob(JB):                         0.00
# Kurtosis:                      21.377   Cond. No.                         302.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS + ESG_Class', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.917
# Model:                             OLS   Adj. R-squared:                  0.917
# Method:                  Least Squares   F-statistic:                     2763.
# Date:                 Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                         12:55:57   Log-Likelihood:                -4728.1
# No. Observations:                  756   AIC:                             9464.
# Df Residuals:                      752   BIC:                             9483.
# Df Model:                            3
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     88.6405     14.821      5.981      0.000      59.545     117.736
# BVE            1.8473      0.151     12.231      0.000       1.551       2.144
# BasicEPS       9.0753      0.387     23.438      0.000       8.315       9.835
# ESG_Class    -13.2149      2.826     -4.677      0.000     -18.762      -7.668
# ==============================================================================
# Omnibus:                      344.290   Durbin-Watson:                   1.386
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18578.592
# Skew:                           1.251   Prob(JB):                         0.00
# Kurtosis:                      27.157   Cond. No.                         302.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model=smf.ols('stock_FollowingQtrEnd ~ BVE + BasicEPS + ESG_Exposure', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                       0.926
# Model:                               OLS   Adj. R-squared:                  0.926
# Method:                    Least Squares   F-statistic:                     3154.
# Date:                   Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                           12:55:57   Log-Likelihood:                -4681.7
# No. Observations:                    756   AIC:                             9371.
# Df Residuals:                        752   BIC:                             9390.
# Df Model:                              3
# Covariance Type:               nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      122.5071     14.332      8.548      0.000      94.371     150.643
# BVE              1.6707      0.142     11.740      0.000       1.391       1.950
# BasicEPS         9.4825      0.366     25.912      0.000       8.764      10.201
# ESG_Exposure    -2.2101      0.306     -7.230      0.000      -2.810      -1.610
# ==============================================================================
# Omnibus:                      433.386   Durbin-Watson:                   1.365
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11426.998
# Skew:                           2.060   Prob(JB):                         0.00
# Kurtosis:                      21.595   Cond. No.                         313.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS + ESG_Exposure', data=DATA)
results=model.fit()
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.920
# Model:                             OLS   Adj. R-squared:                  0.920
# Method:                  Least Squares   F-statistic:                     2885.
# Date:                 Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                         12:55:57   Log-Likelihood:                -4713.1
# No. Observations:                  756   AIC:                             9434.
# Df Residuals:                      752   BIC:                             9453.
# Df Model:                            3
# Covariance Type:             nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      125.8078     14.939      8.421      0.000      96.481     155.135
# BVE              1.8978      0.148     12.794      0.000       1.607       2.189
# BasicEPS         8.8673      0.381     23.247      0.000       8.118       9.616
# ESG_Exposure    -2.3240      0.319     -7.294      0.000      -2.950      -1.699
# ==============================================================================
# Omnibus:                      338.394   Durbin-Watson:                   1.387
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19455.449
# Skew:                           1.195   Prob(JB):                         0.00
# Kurtosis:                      27.737   Cond. No.                         313.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <h2>Estimate a few simple Ohlsson model with robust errors

# %% [markdown]
# You will need to conduct your own research to understand Ohlsson model with robust errors and interpret the statistics in this section. **Report your findings**.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + BasicEPS', data=DATA)
results=model.fit(cov_type='HC1') #HC1 is the Huber-White standard errros, can try HC3 heteroscedasticity-consistent estimator
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.914
# Model:                             OLS   Adj. R-squared:                  0.914
# Method:                  Least Squares   F-statistic:                     66.33
# Date:                 Sun, 06 Jul 2025   Prob (F-statistic):           2.93e-27
# Time:                         13:21:27   Log-Likelihood:                -4738.9
# No. Observations:                  756   AIC:                             9484.
# Df Residuals:                      753   BIC:                             9498.
# Df Model:                            2
# Covariance Type:                   HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.4737     14.105      1.735      0.083      -3.171      52.119
# BVE            1.7980      0.598      3.007      0.003       0.626       2.970
# BasicEPS       9.1982      1.856      4.955      0.000       5.560      12.836
# ==============================================================================
# Omnibus:                      349.831   Durbin-Watson:                   1.366
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18560.548
# Skew:                           1.290   Prob(JB):                         0.00
# Kurtosis:                      27.136   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# Add the ESG risk scores, try a different score one at a time, or a combination of different scores.

# %%
model=smf.ols('stock_FinancialYEnd ~ BVE + +BasicEPS + ESG_Index', data=DATA)
results=model.fit(cov_type='HC1') #HC1 is the Huber-White standard errros, can try HC3 heteroscedasticity-consistent estimator
print(results.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                       0.920
# Model:                             OLS   Adj. R-squared:                  0.920
# Method:                  Least Squares   F-statistic:                     71.76
# Date:                 Sun, 06 Jul 2025   Prob (F-statistic):           8.08e-41
# Time:                         12:55:57   Log-Likelihood:                -4713.1
# No. Observations:                  756   AIC:                             9434.
# Df Residuals:                      752   BIC:                             9453.
# Df Model:                            3
# Covariance Type:                   HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.0863     13.737      1.681      0.093      -3.837      50.009
# BVE            1.8984      0.584      3.248      0.001       0.753       3.044
# BasicEPS       8.8755      1.813      4.895      0.000       5.321      12.430
# ESG_Index    -21.3471      2.968     -7.193      0.000     -27.164     -15.531
# ==============================================================================
# Omnibus:                      339.681   Durbin-Watson:                   1.389
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19506.437
# Skew:                           1.203   Prob(JB):                         0.00
# Kurtosis:                      27.768   Cond. No.                         113.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %%
model=smf.ols('stock_FollowingQtrEnd ~ BVE + +BasicEPS + ESG_Index', data=DATA)
results=model.fit(cov_type='HC1') #HC1 is the Huber-White standard errros, can try HC3 heteroscedasticity-consistent estimator
print(results.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                       0.926
# Model:                               OLS   Adj. R-squared:                  0.926
# Method:                    Least Squares   F-statistic:                     127.0
# Date:                   Sun, 06 Jul 2025   Prob (F-statistic):           1.47e-66
# Time:                           12:55:57   Log-Likelihood:                -4681.8
# No. Observations:                    756   AIC:                             9372.
# Df Residuals:                        752   BIC:                             9390.
# Df Model:                              3
# Covariance Type:                     HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.8247     12.794      1.940      0.052      -0.251      49.900
# BVE            1.6712      0.525      3.183      0.001       0.642       2.700
# BasicEPS       9.4908      1.136      8.358      0.000       7.265      11.716
# ESG_Index    -20.2682      2.945     -6.883      0.000     -26.039     -14.497
# ==============================================================================
# Omnibus:                      433.318   Durbin-Watson:                   1.363
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11356.232
# Skew:                           2.062   Prob(JB):                         0.00
# Kurtosis:                      21.534   Cond. No.                         113.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# <h3>Extract the summary output table

# %% [markdown]
# Must run the following codes right after the model that's been estimated; if you want to report a few different model results, run the following codes after each model estimation, remember to give a differet name in the last line, i.e., 'summary_output_1(2,3,4,etc.)_xlsx'. You will find the output xlsx file under the same folder where you saved this jupter notebook.

# %%
summary = results.summary() 

#extract observations, adjusted r2, f-stats, log likelihood

obs = results.nobs
adjusted_r2 = results.rsquared_adj
f_stats = results.fvalue
log_likelihood = results.llf

#convert the summary output table into a DataFrame

summary_df = pd.read_html(summary.tables[1].as_html(), header=0, index_col=0)[0]

#Add observations, adjusted R-squared, F-statistics, and log-likelihood to the DataFrame
summary_df['Observations'] = obs
summary_df['Adjusted R-squared'] = adjusted_r2
summary_df['F-Statistic'] = f_stats
summary_df['Log-Likelihood'] = log_likelihood

#Export the DataFrame to an Excel file, give a different name if you are exporting a few tables of results, i.e., 'summary_output_1' etc.
#you can find the xlsx file in the same folder where you keep all your Jupyter notebookds and data
#go to the foloder and download it, format it then present it in your report

summary_df.to_excel('summary_output.xlsx')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_26020\2955853338.py:12: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   summary_df = pd.read_html(summary.tables[1].as_html(), header=0, index_col=0)[0]

# %% [markdown]
# <h2>Install linearmodels package to estimate panel data with fixed effects

# %%
pip install linearmodels
# Out:
# Requirement already satisfied: linearmodels in c:\users\admin\anaconda3\lib\site-packages (6.1)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\admin\appdata\roaming\python\python312\site-packages (from linearmodels) (1.26.4)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from linearmodels) (2.2.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\admin\anaconda3\lib\site-packages (from linearmodels) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from linearmodels) (0.14.4)
# Requirement already satisfied: mypy-extensions>=0.4 in c:\users\admin\anaconda3\lib\site-packages (from linearmodels) (1.0.0)
# Requirement already satisfied: Cython>=3.0.10 in c:\users\admin\anaconda3\lib\site-packages (from linearmodels) (3.1.2)
# Requirement already satisfied: pyhdfe>=0.1 in c:\users\admin\anaconda3\lib\site-packages (from linearmodels) (0.2.0)
# Requirement already satisfied: formulaic>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from linearmodels) (1.1.1)
# Requirement already satisfied: setuptools-scm<9.0.0,>=8.0.0 in c:\users\admin\anaconda3\lib\site-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (8.3.1)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from formulaic>=1.0.0->linearmodels) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\admin\anaconda3\lib\site-packages (from formulaic>=1.0.0->linearmodels) (4.13.2)
# Requirement already satisfied: wrapt>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from formulaic>=1.0.0->linearmodels) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.0->linearmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.0->linearmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=1.4.0->linearmodels) (2023.3)
# Requirement already satisfied: packaging>=20 in c:\users\admin\anaconda3\lib\site-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (23.2)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (69.5.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels>=0.13.0->linearmodels) (0.5.6)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.13.0->linearmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h2>From linearmodels import PanelOLS the fixed effect package

# %%
from linearmodels import PanelOLS
import statsmodels.api as sm
import pandas as pd

# %% [markdown]
# <h2>Estimate a fixed effect model, print out the stats, export the results, report them and discuss the results in your report

# %% [markdown]
# To estimate a fixed effect model first must organise the data into panel data and let pandas know what variable (column name) is 'entity' and what variable (column name) is 'time'
#
# https://bashtage.github.io/linearmodels/panel/panel/linearmodels.panel.model.PanelOLS.html
# https://timeseriesreasoning.com/contents/the-fixed-effects-regression-model-for-panel-data-sets/#google_vignette
# https://swh.princeton.edu/~otorres/Panel101.pdf
#
# We encourage you to write differnt codes to find a best fit model, i.e., all coefficients are significant (if possible) with high R square. You can consult your lecturers about how you can find the best model using panel data.
#
# If the fixed effect models perform poorer than the simple OLS or simple OLS with robust errors, **include your results in your report as sensitive analyses** and state that you have tried other models; then focus on interpretting the models that yield the best results.

# %% [markdown]
# Step 1: Organise the data into a panel data format.
# Specify `Company` and `Year` are the fixed effects.
# The order matters!
# The first in the `set_index` code tells Python that variable is the 'entity' fixed effect, the second is the 'time' fixed effect.

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['Company', 'Year'])

# %% [markdown]
# Step 2: Define `stock_FinancialYEnd` as the dependent variable (y) and `BVE`, `BasicEPS` as the independent variables (X)

# %%
#define the dependent variable
y = FixedEffect['stock_FinancialYEnd']

#define the independent variables and add constant to the model
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS']])

# %% [markdown]
# Step 3: Estimate the fixed effect model with entity fixed effect; and print the results.

# %%
Model_F = PanelOLS(y, X, entity_effects=True) #entity here is 'Company' which is the firm fixed effect
results = Model_F.fit()
print(results)
# Out:
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.7654
# Estimator:                    PanelOLS   R-squared (Between):              0.8413
# No. Observations:                  756   R-squared (Within):               0.7654
# Date:                 Sun, Jul 06 2025   R-squared (Overall):              0.8363
# Time:                         12:56:03   Log-likelihood                   -4086.1
# Cov. Estimator:             Unadjusted
#                                          F-statistic:                      921.78
# Entities:                          189   P-value                           0.0000
# Avg Obs:                        4.0000   Distribution:                   F(2,565)
# Min Obs:                        4.0000
# Max Obs:                        4.0000   F-statistic (robust):             921.78
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(2,565)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -57.670     5.9824    -9.6399     0.0000     -69.421     -45.920
# BVE            5.7911     0.1837     31.527     0.0000      5.4303      6.1519
# BasicEPS       0.0364     0.3291     0.1107     0.9119     -0.6100      0.6829
# ==============================================================================
#
# F-test for Poolability: 13.898
# P-value: 0.0000
# Distribution: F(188,565)
#
# Included effects: Entity

# %% [markdown]
# You can specify `SECTOR` as the entity fixed effect. We encourage you to write different codes to find a best fit model.

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])

y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS']])

Model_F = PanelOLS(y, X, entity_effects=True) #entity here is 'SECTOR' which is the SECTOR fixed effect
results = Model_F.fit()
print(results)
# Out:
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.9187
# Estimator:                    PanelOLS   R-squared (Between):              0.8434
# No. Observations:                  756   R-squared (Within):               0.9187
# Date:                 Sun, Jul 06 2025   R-squared (Overall):              0.9140
# Time:                         12:56:03   Log-likelihood                   -4696.0
# Cov. Estimator:             Unadjusted
#                                          F-statistic:                      4201.3
# Entities:                           10   P-value                           0.0000
# Avg Obs:                        75.600   Distribution:                   F(2,744)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             4201.3
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(2,744)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          21.691     5.4330     3.9924     0.0001      11.025      32.357
# BVE            2.0082     0.1492     13.458     0.0000      1.7153      2.3012
# BasicEPS       8.5064     0.3855     22.065     0.0000      7.7496      9.2632
# ==============================================================================
#
# F-test for Poolability: 9.9475
# P-value: 0.0000
# Distribution: F(9,744)
#
# Included effects: Entity

# %% [markdown]
# Step 4: Estimate the fixed effect model with both the `Company` and `Year` fixed effect; print the results.
# In the following model, we change entity back to `Company`.

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['Company', 'Year'])

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#entity here is 'Company' which is the firm fixed effect; time here is 'Year' which is the time fixed effect

results = Model_F.fit()
print(results)
# Out:
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.9202
# Estimator:                    PanelOLS   R-squared (Between):              0.8466
# No. Observations:                  756   R-squared (Within):               0.9186
# Date:                 Sun, Jul 06 2025   R-squared (Overall):              0.9142
# Time:                         12:56:03   Log-likelihood                   -4687.9
# Cov. Estimator:             Unadjusted
#                                          F-statistic:                      4272.9
# Entities:                           10   P-value                           0.0000
# Avg Obs:                        75.600   Distribution:                   F(2,741)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             4272.9
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(2,741)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          22.755     5.3938     4.2187     0.0000      12.166      33.344
# BVE            1.9425     0.1489     13.043     0.0000      1.6502      2.2349
# BasicEPS       8.6961     0.3854     22.561     0.0000      7.9394      9.4528
# ==============================================================================
#
# F-test for Poolability: 8.9195
# P-value: 0.0000
# Distribution: F(12,741)
#
# Included effects: Entity, Time

# %% [markdown]
# Add other variables in the right hand side, i.e., `ESG_Index`. We also cluster the robust errors by entity and time in the estimation. Try different model specifications to find the best model, **report and interpret the results**.

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Index']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.9214
# Estimator:                    PanelOLS   R-squared (Between):              0.9163
# No. Observations:                  756   R-squared (Within):               0.9199
# Date:                 Sun, Jul 06 2025   R-squared (Overall):              0.9196
# Time:                         12:56:03   Log-likelihood                   -4682.0
# Cov. Estimator:              Clustered
#                                          F-statistic:                      2893.4
# Entities:                           10   P-value                           0.0000
# Avg Obs:                        75.600   Distribution:                   F(3,740)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             699.46
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(3,740)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          21.954     12.338     1.7794     0.0756     -2.2672      46.174
# BVE            1.9891     0.5338     3.7262     0.0002      0.9411      3.0371
# BasicEPS       8.5679     1.3031     6.5753     0.0000      6.0098      11.126
# ESG_Index     -15.921     4.5966    -3.4636     0.0006     -24.945     -6.8968
# ==============================================================================
#
# F-test for Poolability: 5.2872
# P-value: 0.0000
# Distribution: F(12,740)
#
# Included effects: Entity, Time
# """

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['Company', 'Year'])
y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Index']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.7625
# Estimator:                    PanelOLS   R-squared (Between):              0.8424
# No. Observations:                  756   R-squared (Within):               0.7653
# Date:                 Sun, Jul 06 2025   R-squared (Overall):              0.8374
# Time:                         12:56:03   Log-likelihood                   -4079.5
# Cov. Estimator:              Clustered
#                                          F-statistic:                      600.28
# Entities:                          189   P-value                           0.0000
# Avg Obs:                        4.0000   Distribution:                   F(3,561)
# Min Obs:                        4.0000
# Max Obs:                        4.0000   F-statistic (robust):            -59.102
#                                          P-value                           1.0000
# Time periods:                        4   Distribution:                   F(3,561)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -57.654     47.443    -1.2152     0.2248     -150.84      35.533
# BVE            5.7598     1.6799     3.4287     0.0007      2.4602      9.0595
# BasicEPS       0.1932     2.2731     0.0850     0.9323     -4.2716      4.6581
# ESG_Index     -0.1142     10.390    -0.0110     0.9912     -20.522      20.294
# ==============================================================================
#
# F-test for Poolability: 12.763
# P-value: 0.0000
# Distribution: F(191,561)
#
# Included effects: Entity, Time
# """

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FollowingQtrEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Index']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                             PanelOLS Estimation Summary
# ===================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                        0.9289
# Estimator:                      PanelOLS   R-squared (Between):              0.9212
# No. Observations:                    756   R-squared (Within):               0.9260
# Date:                   Sun, Jul 06 2025   R-squared (Overall):              0.9257
# Time:                           12:56:03   Log-likelihood                   -4644.7
# Cov. Estimator:                Clustered
#                                            F-statistic:                      3221.4
# Entities:                             10   P-value                           0.0000
# Avg Obs:                          75.600   Distribution:                   F(3,740)
# Min Obs:                          56.000
# Max Obs:                          80.000   F-statistic (robust):             1332.2
#                                            P-value                           0.0000
# Time periods:                          4   Distribution:                   F(3,740)
# Avg Obs:                          189.00
# Min Obs:                          189.00
# Max Obs:                          189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          24.115     10.646     2.2651     0.0238      3.2144      45.015
# BVE            1.7310     0.4262     4.0616     0.0001      0.8943      2.5677
# BasicEPS       9.2829     1.0069     9.2193     0.0000      7.3062      11.260
# ESG_Index     -13.486     5.0369    -2.6775     0.0076     -23.374     -3.5978
# ==============================================================================
#
# F-test for Poolability: 6.3725
# P-value: 0.0000
# Distribution: F(12,740)
#
# Included effects: Entity, Time
# """

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['Company', 'Year'])
y = FixedEffect['stock_FollowingQtrEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Index']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                             PanelOLS Estimation Summary
# ===================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                        0.7223
# Estimator:                      PanelOLS   R-squared (Between):              0.8886
# No. Observations:                    756   R-squared (Within):               0.7128
# Date:                   Sun, Jul 06 2025   R-squared (Overall):              0.8782
# Time:                           12:56:03   Log-likelihood                   -4106.5
# Cov. Estimator:                Clustered
#                                            F-statistic:                      486.29
# Entities:                            189   P-value                           0.0000
# Avg Obs:                          4.0000   Distribution:                   F(3,561)
# Min Obs:                          4.0000
# Max Obs:                          4.0000   F-statistic (robust):            -16.599
#                                            P-value                           1.0000
# Time periods:                          4   Distribution:                   F(3,561)
# Avg Obs:                          189.00
# Min Obs:                          189.00
# Max Obs:                          189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const         -29.332     36.623    -0.8009     0.4235     -101.27      42.603
# BVE            4.5508     1.2021     3.7857     0.0002      2.1897      6.9120
# BasicEPS       2.1939     0.9272     2.3662     0.0183      0.3727      4.0151
# ESG_Index     -2.6270     10.039    -0.2617     0.7937     -22.346      17.092
# ==============================================================================
#
# F-test for Poolability: 10.519
# P-value: 0.0000
# Distribution: F(191,561)
#
# Included effects: Entity, Time
# """

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FollowingQtrEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Exposure']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                             PanelOLS Estimation Summary
# ===================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                        0.9289
# Estimator:                      PanelOLS   R-squared (Between):              0.9227
# No. Observations:                    756   R-squared (Within):               0.9260
# Date:                   Sun, Jul 06 2025   R-squared (Overall):              0.9258
# Time:                           12:56:03   Log-likelihood                   -4644.8
# Cov. Estimator:                Clustered
#                                            F-statistic:                      3220.7
# Entities:                             10   P-value                           0.0000
# Avg Obs:                          75.600   Distribution:                   F(3,740)
# Min Obs:                          56.000
# Max Obs:                          80.000   F-statistic (robust):             1173.7
#                                            P-value                           0.0000
# Time periods:                          4   Distribution:                   F(3,740)
# Avg Obs:                          189.00
# Min Obs:                          189.00
# Max Obs:                          189.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            90.008     25.653     3.5087     0.0005      39.647      140.37
# BVE              1.7305     0.4264     4.0579     0.0001      0.8933      2.5677
# BasicEPS         9.2799     1.0092     9.1951     0.0000      7.2986      11.261
# ESG_Exposure    -1.4911     0.5977    -2.4947     0.0128     -2.6645     -0.3177
# ================================================================================
#
# F-test for Poolability: 6.3361
# P-value: 0.0000
# Distribution: F(12,740)
#
# Included effects: Entity, Time
# """

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FollowingQtrEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Managed']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                             PanelOLS Estimation Summary
# ===================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                        0.9284
# Estimator:                      PanelOLS   R-squared (Between):              0.9092
# No. Observations:                    756   R-squared (Within):               0.9258
# Date:                   Sun, Jul 06 2025   R-squared (Overall):              0.9248
# Time:                           12:56:03   Log-likelihood                   -4647.1
# Cov. Estimator:                Clustered
#                                            F-statistic:                      3199.2
# Entities:                             10   P-value                           0.0000
# Avg Obs:                          75.600   Distribution:                   F(3,740)
# Min Obs:                          56.000
# Max Obs:                          80.000   F-statistic (robust):            -322.90
#                                            P-value                           1.0000
# Time periods:                          4   Distribution:                   F(3,740)
# Avg Obs:                          189.00
# Min Obs:                          189.00
# Max Obs:                          189.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const           56.599     11.518     4.9138     0.0000      33.986      79.212
# BVE             1.7088     0.4338     3.9394     0.0001      0.8572      2.5603
# BasicEPS        9.3264     1.0215     9.1300     0.0000      7.3210      11.332
# ESG_Managed    -1.6140     0.9695    -1.6649     0.0964     -3.5172      0.2892
# ===============================================================================
#
# F-test for Poolability: 5.8047
# P-value: 0.0000
# Distribution: F(12,740)
#
# Included effects: Entity, Time
# """

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FollowingQtrEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Class']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                             PanelOLS Estimation Summary
# ===================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                        0.9285
# Estimator:                      PanelOLS   R-squared (Between):              0.8848
# No. Observations:                    756   R-squared (Within):               0.9254
# Date:                   Sun, Jul 06 2025   R-squared (Overall):              0.9230
# Time:                           12:56:04   Log-likelihood                   -4646.5
# Cov. Estimator:                Clustered
#                                            F-statistic:                      3204.9
# Entities:                             10   P-value                           0.0000
# Avg Obs:                          75.600   Distribution:                   F(3,740)
# Min Obs:                          56.000
# Max Obs:                          80.000   F-statistic (robust):             4339.6
#                                            P-value                           0.0000
# Time periods:                          4   Distribution:                   F(3,740)
# Avg Obs:                          189.00
# Min Obs:                          189.00
# Max Obs:                          189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          62.914     21.904     2.8723     0.0042      19.913      105.92
# BVE            1.7174     0.4195     4.0941     0.0000      0.8939      2.5410
# BasicEPS       9.3403     1.0027     9.3150     0.0000      7.3718      11.309
# ESG_Class     -7.8574     2.9867    -2.6308     0.0087     -13.721     -1.9940
# ==============================================================================
#
# F-test for Poolability: 8.7803
# P-value: 0.0000
# Distribution: F(12,740)
#
# Included effects: Entity, Time
# """

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Exposure']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.9214
# Estimator:                    PanelOLS   R-squared (Between):              0.9176
# No. Observations:                  756   R-squared (Within):               0.9198
# Date:                 Sun, Jul 06 2025   R-squared (Overall):              0.9196
# Time:                         12:56:04   Log-likelihood                   -4682.2
# Cov. Estimator:              Clustered
#                                          F-statistic:                      2891.8
# Entities:                           10   P-value                           0.0000
# Avg Obs:                        75.600   Distribution:                   F(3,740)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             580.07
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(3,740)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            99.144     26.320     3.7668     0.0002      47.473      150.82
# BVE              1.9881     0.5344     3.7200     0.0002      0.9389      3.0373
# BasicEPS         8.5654     1.3075     6.5510     0.0000      5.9985      11.132
# ESG_Exposure    -1.7466     0.5580    -3.1301     0.0018     -2.8420     -0.6511
# ================================================================================
#
# F-test for Poolability: 5.2462
# P-value: 0.0000
# Distribution: F(12,740)
#
# Included effects: Entity, Time
# """

# %%
params_df = pd.DataFrame({
    'Parameter': results.params,
    'Std. Err.': results.std_errors,
    'T-stat': results.tstats,
    'P-value': results.pvalues,
    'Lower CI': results.conf_int().iloc[:, 0],
    'Upper CI': results.conf_int().iloc[:, 1]
})

# Reset index to include the parameter names as a column
params_df = params_df.reset_index().rename(columns={'index': 'Variable'})

params_df[' '] = np.nan  # Adds an empty column named with a space
# Step 3: Add additional model statistics to the DataFrame
additional_stats = {
    'R-squared': [results.rsquared],
    'No. Observations': [results.nobs],
}

# Convert the additional statistics dictionary into a DataFrame
additional_stats_df = pd.DataFrame(additional_stats)

# Step 4: Combine parameter estimates with the additional statistics
combined_df = pd.concat([params_df, additional_stats_df], axis=1)

combined_df.to_excel('panel_ols_summary_output.xlsx', index=False, float_format=None)

print("Summary output exported to 'panel_ols_summary_output.xlsx'") ##use different file names for different models otherwise the file will overwrite saved results
# Out:
# Summary output exported to 'panel_ols_summary_output.xlsx'

# %% [markdown]
# <h2>Optional: Additional analyses

# %% [markdown]
# <H3>Drop SECTOR = Energy, renmae the dataframe as 'data'

# %%
data = DATA[DATA['SECTOR'] != 9]
FixedEffect=pd.DataFrame(data).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Index']])

#Try all different ESG risk scores and interpret the results accordingly

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#Try different clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.9297
# Estimator:                    PanelOLS   R-squared (Between):              0.9166
# No. Observations:                  676   R-squared (Within):               0.9281
# Date:                 Sun, Jul 06 2025   R-squared (Overall):              0.9273
# Time:                         12:56:04   Log-likelihood                   -4181.8
# Cov. Estimator:              Clustered
#                                          F-statistic:                      2915.7
# Entities:                            9   P-value                           0.0000
# Avg Obs:                        75.111   Distribution:                   F(3,661)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             812.00
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(3,661)
# Avg Obs:                        169.00
# Min Obs:                        169.00
# Max Obs:                        169.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          22.404     13.180     1.6998     0.0896     -3.4759      48.284
# BVE            2.0447     0.6101     3.3516     0.0008      0.8468      3.2427
# BasicEPS       8.4265     1.5013     5.6128     0.0000      5.4786      11.374
# ESG_Index     -16.241     4.7216    -3.4397     0.0006     -25.512     -6.9698
# ==============================================================================
#
# F-test for Poolability: 5.5951
# P-value: 0.0000
# Distribution: F(11,661)
#
# Included effects: Entity, Time
# """

# %% [markdown]
# <h4>There is a slight improvement in the model fit.

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Plot a few scenarios to visualise the impacts of varying independent variables on the dependent variable

# %%
FixedEffect=pd.DataFrame(DATA).set_index(['SECTOR', 'Year'])
y = FixedEffect['stock_FinancialYEnd']
X = sm.add_constant(FixedEffect[['BVE', 'BasicEPS', 'ESG_Index']])

Model_F = PanelOLS(y, X, entity_effects=True, time_effects=True) 

#clusters
results = Model_F.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                            PanelOLS Estimation Summary
# =================================================================================
# Dep. Variable:     stock_FinancialYEnd   R-squared:                        0.9214
# Estimator:                    PanelOLS   R-squared (Between):              0.9163
# No. Observations:                  756   R-squared (Within):               0.9199
# Date:                 Sun, Jul 06 2025   R-squared (Overall):              0.9196
# Time:                         12:56:04   Log-likelihood                   -4682.0
# Cov. Estimator:              Clustered
#                                          F-statistic:                      2893.4
# Entities:                           10   P-value                           0.0000
# Avg Obs:                        75.600   Distribution:                   F(3,740)
# Min Obs:                        56.000
# Max Obs:                        80.000   F-statistic (robust):             699.46
#                                          P-value                           0.0000
# Time periods:                        4   Distribution:                   F(3,740)
# Avg Obs:                        189.00
# Min Obs:                        189.00
# Max Obs:                        189.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          21.954     12.338     1.7794     0.0756     -2.2672      46.174
# BVE            1.9891     0.5338     3.7262     0.0002      0.9411      3.0371
# BasicEPS       8.5679     1.3031     6.5753     0.0000      6.0098      11.126
# ESG_Index     -15.921     4.5966    -3.4636     0.0006     -24.945     -6.8968
# ==============================================================================
#
# F-test for Poolability: 5.2872
# P-value: 0.0000
# Distribution: F(12,740)
#
# Included effects: Entity, Time
# """

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the data
DATA = pd.read_csv('DATA.csv')  # Assuming the data file is 'DATA.csv'

# Step 2: Define independent and dependent variables
# Define dependent variable (stock price: stock_FinancialYEnd)
y = DATA['stock_FollowingQtrEnd']

# Define independent variables (BVE, BasicEPS, ESG_Index)
X = DATA[['BVE', 'BasicEPS', 'ESG_Index']]

# Step 3: Add constant to the model
X = sm.add_constant(X)

# Step 4: Fit the OLS regression model
model = sm.OLS(y, X).fit()

# Print model summary
print(model.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     stock_FollowingQtrEnd   R-squared:                       0.926
# Model:                               OLS   Adj. R-squared:                  0.926
# Method:                    Least Squares   F-statistic:                     3153.
# Date:                   Sun, 06 Jul 2025   Prob (F-statistic):               0.00
# Time:                           12:56:04   Log-Likelihood:                -4681.8
# No. Observations:                    756   AIC:                             9372.
# Df Residuals:                        752   BIC:                             9390.
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         24.8247      5.274      4.707      0.000      14.471      35.178
# BVE            1.6712      0.142     11.741      0.000       1.392       1.951
# BasicEPS       9.4908      0.366     25.940      0.000       8.773      10.209
# ESG_Index    -20.2682      2.810     -7.212      0.000     -25.785     -14.751
# ==============================================================================
# Omnibus:                      433.318   Durbin-Watson:                   1.363
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11356.232
# Skew:                           2.062   Prob(JB):                         0.00
# Kurtosis:                      21.534   Cond. No.                         113.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Step 5: Define scenarios with all variables
scenarios = {
    'Baseline': {'BasicEPS': 1.0, 'BVE': 1.0, 'ESG_Index': 1.0},  # Baseline scenario
    'Increase BVE by 10%': {'BVE': 1.10, 'ESG_Index': 1.0, 'BasicEPS': 1.0},
    'Decrease BVE by 10%': {'BVE': 0.90, 'ESG_Index': 1.0, 'BasicEPS': 1.0},
    'Increase ESG_Index by 20%': {'BVE': 1.0, 'ESG_Index': 1.20, 'BasicEPS': 1.0},
    'Decrease ESG_Index by 20%': {'BVE': 1.0, 'ESG_Index': 0.80, 'BasicEPS': 1.0},
    'Increase BasicEPS by 15%': {'BVE': 1.0, 'ESG_Index': 1.0, 'BasicEPS': 1.15},
    'Decrease BasicEPS by 15%': {'BVE': 1.0, 'ESG_Index': 1.0, 'BasicEPS': 0.85},
}

# %%
# Step 6: Run simulations for different scenarios
results = {}

for scenario, changes in scenarios.items():
    # Modify independent variables based on the scenario
    DATA['BasicEPS_new'] = DATA['BasicEPS'] * changes['BasicEPS']
    DATA['ESG_Index_new'] = DATA['ESG_Index'] * changes['ESG_Index']
    DATA['BVE_new'] = DATA['BVE'] * changes['BVE']

# Build a new independent variable matrix using the modified data
    X_new = DATA[['BasicEPS_new', 'BVE_new', 'ESG_Index_new']]
    X_new = sm.add_constant(X_new)
    
    # Predict the stock price using the regression model
    stock_FinancialYEnd_predicted = model.predict(X_new)
    
    # Store results
    results[scenario] = stock_FinancialYEnd_predicted

# %%
# Step 7: Visualize the stock price predictions for different scenarios
plt.figure(figsize=(10,6))
plt.plot(DATA['stock_FinancialYEnd'], label='Actual Stock Price', color='blue', marker='o')
for scenario, prediction in results.items():
    plt.plot(prediction, label=f'Predicted Stock Price ({scenario})', marker='x')
plt.title('What-If Simulation: Impact of Changes in BasicEPS, BVE, and ESG_Index')
plt.xlabel('Data Points')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Step 8: Analyze the sensitivity of each variable
# Calculate the mean change in each scenario
for scenario, prediction in results.items():
    mean_predicted = prediction.mean()
    print(f"Mean predicted stock price in the {scenario} scenario: {mean_predicted}")

# Step 9: Verify the model assumptions
# Compare the deviation of each scenario from the baseline
baseline_mean = results['Baseline'].mean()
for scenario, prediction in results.items():
    mean_predicted = prediction.mean()
    deviation = abs(mean_predicted - baseline_mean)
    print(f"Deviation from baseline in the {scenario} scenario: {deviation}")
# Out:
# Mean predicted stock price in the Baseline scenario: 392.77227869845365
# Mean predicted stock price in the Increase BVE by 10% scenario: 428.3360243950576
# Mean predicted stock price in the Decrease BVE by 10% scenario: 357.20853300184984
# Mean predicted stock price in the Increase ESG_Index by 20% scenario: 392.77227869845365
# Mean predicted stock price in the Decrease ESG_Index by 20% scenario: 392.77227869845365
# Mean predicted stock price in the Increase BasicEPS by 15% scenario: 394.61879511714
# Mean predicted stock price in the Decrease BasicEPS by 15% scenario: 390.92576227976747
# Deviation from baseline in the Baseline scenario: 0.0
# Deviation from baseline in the Increase BVE by 10% scenario: 35.563745696603974
# Deviation from baseline in the Decrease BVE by 10% scenario: 35.5637456966038
# Deviation from baseline in the Increase ESG_Index by 20% scenario: 0.0
# Deviation from baseline in the Decrease ESG_Index by 20% scenario: 0.0
# Deviation from baseline in the Increase BasicEPS by 15% scenario: 1.846516418686349
# Deviation from baseline in the Decrease BasicEPS by 15% scenario: 1.8465164186861784

# %% [markdown]
# <h1>The End
